# %%
# %fs ls 'abfss://demo@databrickslearningmanoj.dfs.core.windows.net/'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS databrickslearningmanoj_demo
    URL 'abfss://demo@databrickslearningmanoj.dfs.core.windows.net/'
    WITH (STORAGE CREDENTIAL databricks_ws)
    COMMENT 'Demo'
