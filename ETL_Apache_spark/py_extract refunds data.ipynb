# %% [markdown]
# #Extract Refunds Data

# %% [markdown]
# ##Done using delta lakehouse federation by creating connection between azure db and databricks - hive meta store/jdbc is currently being deprecated

# %%
df = spark.table('asql_gizmobox_db_conn_catalog.dbo.refunds')
display(df)

# %%
df.writeTo('gizmobox.bronze.py_refunds').createOrReplace()
