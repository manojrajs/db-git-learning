-- %% [markdown]
-- ##extract data from payment files

-- %%
%fs ls 'abfss://gizmobox@databrickslearningmanoj.dfs.core.windows.net/Landing/external_data/payments'

-- %% [markdown]
-- ##create external tables

-- %%
%sql
create table if not exists gizmobox.bronze.payments 
(payment_id int, order_id int, payment_timestamp timestamp, payment_status int, payment_method string)
using csv
options 
(
    header = true,
    delimeter = ','
)
location 'abfss://gizmobox@databrickslearningmanoj.dfs.core.windows.net/Landing/external_data/payments'

-- %%
%sql
select * from gizmobox.bronze.payments

-- %%
describe extended gizmobox.bronze.payments

-- %% [markdown]
-- ##effect of adding/deleting/updating file
--
-- 1. for every addition or deletion or updation of tables from external table, we need to refresh the table

-- %%
Refresh table gizmobox.bronze.payments

-- %% [markdown]
-- ##dropping external table

-- %%
drop table if exists gizmobox.bronze.payments
